# %% [markdown]
# # Investigation: Auth0 User Joined Tenant
#
# This notebook assists in investigating alerts related to users joining the tenant.

# %%
from scanner_client import ScannerClient
import pandas as pd

# Initialize Scanner Client
client = ScannerClient(api_url="https://api.kast-apse1.scanner.dev", api_key="YOUR_API_KEY")

# %%
query = """
# %ingest.source_type:auth0
data.description:'Update an invitation'
data.details.request.body.state:accepted
"""

results = client.query(query, time_range_s=86400)
df = pd.DataFrame(results)
df.head()

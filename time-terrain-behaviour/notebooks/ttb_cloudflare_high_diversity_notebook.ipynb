# %% [markdown]
# # Cloudflare TTB High Diversity Anomaly Investigation
#
# ## Goal
# Investigate anomalous high-velocity behavior for cloudflare.

# %%
# %ingest.source_type:"cloudflare"
| stats distinct_count(ZoneName) as terrain, distinct_count(ClientRequestURI) as behavior by ClientIP
| sort -terrain -behavior

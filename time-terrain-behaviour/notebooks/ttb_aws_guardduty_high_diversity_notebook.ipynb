# %% [markdown]
# # AWS GuardDuty TTB High Diversity Anomaly Investigation
#
# ## Goal
# Investigate anomalous high-velocity behavior for aws:guardduty.

# %%
# %ingest.source_type:"aws:guardduty"
| stats distinct_count(region) as terrain, distinct_count(type) as behavior by resource.instanceDetails.instanceId
| sort -terrain -behavior

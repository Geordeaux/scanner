# %% [markdown]
# # Atlassian TTB High Diversity Anomaly Investigation
#
# ## Goal
# Investigate anomalous high-velocity behavior for atlassian.

# %%
# %ingest.source_type:"atlassian"
| stats distinct_count(event_source) as terrain, distinct_count(event_key) as behavior by actor.displayName
| sort -terrain -behavior

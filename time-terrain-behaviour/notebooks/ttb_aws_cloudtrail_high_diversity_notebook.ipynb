# %% [markdown]
# # AWS CloudTrail TTB High Diversity Anomaly Investigation
#
# ## Goal
# Investigate anomalous high-velocity behavior for aws:cloudtrail.

# %%
# %ingest.source_type:"aws:cloudtrail"
| stats distinct_count(eventSource) as terrain, distinct_count(eventName) as behavior by userIdentity.arn
| sort -terrain -behavior

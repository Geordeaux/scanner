# %% [markdown]
# # Auth0 TTB High Diversity Anomaly Investigation
#
# ## Goal
# Investigate anomalous high-velocity behavior for auth0.

# %%
# %ingest.source_type:"auth0"
| stats distinct_count(client_name) as terrain, distinct_count(type) as behavior by user_name
| sort -terrain -behavior

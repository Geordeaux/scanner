# %% [markdown]
# # Google Workspace TTB High Diversity Anomaly Investigation
#
# ## Goal
# Investigate anomalous high-velocity behavior for google_workspace.

# %%
# %ingest.source_type:"google_workspace"
| stats distinct_count(id.applicationName) as terrain, distinct_count(events.type) as behavior by actor.email
| sort -terrain -behavior

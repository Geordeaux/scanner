# %% [markdown]
# # GitHub TTB High Diversity Anomaly Investigation
#
# ## Goal
# Investigate anomalous high-velocity behavior for github.

# %%
# %ingest.source_type:"github"
| stats distinct_count(repository.name) as terrain, distinct_count(action) as behavior by actor
| sort -terrain -behavior
